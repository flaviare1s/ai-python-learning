# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviare1s/ai-python-learning/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python - Geração Tech

# %% [markdown]
# ## Fundamentos

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print('Segundo Sócrates: "Só sei que nada sei!"')
# Out:
# Segundo Sócrates: "Só sei que nada sei!"

# %%
type("Oi!")
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
type(0.2)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# ## Variáveis

# %%
nome = "Lucas"
idade = 18
altura = 1.75
estudante = True

# %%
print("O meu amigo", nome, "tem", idade, "anos.")
# Out:
# O meu amigo Lucas tem 18 anos.

# %%
print(f"O meu anigo {nome} tem {idade} anos e mede {altura}m.")
# Out:
# O meu anigo Lucas tem 18 anos e mede 1.75m.

# %%
print(f"O meu amigo {nome} tem {idade} anos e mede {str(altura).replace('.', ',')}m.")
# Out:
# O meu amigo Lucas tem 18 anos e mede 1,75m.

# %% [markdown]
# ## Input

# %%
nome = input("Digite o nome: ")
# Out:
# Digite o nome: Matheus

# %%
print(f"O meu amigo {nome} tem {idade} anos e mede {str(altura).replace('.', ',')}m.")
# Out:
# O meu amigo Matheus tem 18 anos e mede 1,75m.

# %%
idade = input("Digite a idade: ")
# Out:
# Digite a idade: 17

# %%
print(f"O meu amigo {nome} tem {idade} anos e mede {str(altura).replace('.', ',')}m.")
# Out:
# O meu amigo Matheus tem 17 anos e mede 1,75m.

# %%
type(idade)
# Out:
# str

# %%
idade = int(input("Digite a idade: "))
# Out:
# Digite a idade: 20

# %%
type(idade)
# Out:
# int
